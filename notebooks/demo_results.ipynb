# %%
import os
import numpy as np
import pandas as pd
import sys
import tqdm

sys.path.append('..')
from anomalies.increasing import *
from anomalies.invariant import *
from anomalies.decreasing import *

from detectors.feature_based import *
from detectors.pca_based import *
from detectors.gaussian_distribution_based import *
from detectors.ml_based import *
from datasets.data_utils import load_data_training, load_data_test

import matplotlib.pyplot as plt
# %matplotlib widget
import cmasher as cmr
cmap = cmr.get_sub_cmap('brg', 0.5, 1)
import dataframe_image as dfi
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipykernel_434961/3702129504.py in <module>
#       6
#       7 sys.path.append('..')
# ----> 8 from wombats.anomalies.increasing import *
#       9 from anomalies.invariant import *
#      10 from anomalies.decreasing import *
#
# ModuleNotFoundError: No module named 'wombats'

# %% [markdown]
# ## Setup

# %%
data_type = 'bridge'
delta = 0.02
metric = 'P_D'
  
N_train = None
gamma = 'scale'

if data_type == 'ecg':
    channels = ['z']
    n = len(channels)*256
    SNRdB = 40
    
    k1 = 52
    k2 = 59
    
    p1 = 4
    p2 = 16
    
    nu = 0.01
    kernel = 'poly'
    degree = 3
    k1 = 52
    
    h = 5
    l = 250
    
elif data_type == 'bridge':
    channels = ['x']
    n = len(channels)*100
    SNRdB = None

    k1 = 16
    k2 = 85

    p1 = 4
    p2 = 16

    nu = 0.01
    kernel = 'rbf'

    h = 5
    l = 500

# %% [markdown]
# ## Load train data

# %%
Xok_train, Xok_val = load_data_training(channels, n, data_type)
Xok_train = Xok_train[..., -1]
Xok_val = Xok_val[..., -1]

# %% [markdown]
# ## Train detectors

# %%
detectors_labels = [f'SPE_{k1}', f'SPE_{k2}', f'T2_{k1}', f'T2_{k2}', f'AR_{p1}', f'AR_{p2}', 'MD', f'OCSVM_{kernel}_{nu}', f'LOF_{h}',f'IF_{l}', 'energy', 'TV', 'ZC', 'pk-pk']
detectors = [SPE(k1), SPE(k2), T2(k1), T2(k2), AR(p1), AR(p2), MD(), OCSVM(kernel, nu), LOF(h), IF(l), energy(), TV(), ZC(), pk_pk()]
detectors_dict = dict(zip(detectors_labels, detectors))

for detector_label, detector in tqdm.tqdm(detectors_dict.items()):
    detectors_dict[detector_label] = detector.fit(Xok_train[:N_train])
# Out:
# 100%|██████████| 14/14 [00:28<00:00,  2.03s/it]

# %% [markdown]
# ## Load test data

# %%
Xok_test = load_data_test(channels, n, data_type)[..., -1]

# %% [markdown]
# ## Generate Anomalies

# %%
anomalies_labels = [
    'GWN', 'Impulse', 'Step', 'Constant',  
    'GNN',
    'MixingGWN', 'MixingConstant',
    'SpectralAlteration', 'PrincipalSubspaceAlteration',
    'TimeWarping',
    'Clipping', 'Dead-Zone'
]

# # create anomalies class instance
anomalies = [
    GWN(delta), Impulse(delta), Step(delta), Constant(delta),  
    GNN(delta),
    MixingGWN(delta), MixingConstant(delta),
    SpectralAlteration(delta), PrincipalSubspaceAlteration(delta),
    TimeWarping(delta), 
    Clipping(delta), DeadZone(delta)
]

anomalies_dict = dict(zip(anomalies_labels, anomalies))

# initialize the dataframe for anomalous data
Xko_df = pd.DataFrame(
    index=np.arange(Xok_test.shape[0]),
    columns=pd.MultiIndex.from_product([anomalies_labels, np.arange(Xok_test.shape[1])])
)

# generate anomalous data for each anomaly
for anomaly_label, anomaly in tqdm.tqdm(anomalies_dict.items()):
    if anomaly_label in ['SpectralAlteration']:
        anomaly.fit(Xok_test, SNRdB)
    else:
        anomaly.fit(Xok_test)
    # Xko_df.loc[0, name] = anomaly.distort(ECG_test.values[0])
    Xko_df[anomaly_label] = anomaly.distort(Xok_test)
# Out:
# 100%|██████████| 12/12 [03:10<00:00, 15.88s/it]

# %% [markdown]
# ## Evaluate detectors

# %%
result = pd.DataFrame(index=anomalies_labels, columns=detectors_labels, dtype=np.float64)

for detector_label, detector in tqdm.tqdm(detectors_dict.items()):
    for anomaly_label in anomalies_labels:
        Xko_test = Xko_df[anomaly_label].values
        X_anom = np.concatenate([Xok_test, Xko_test])
        metric_value = detector.test(X_anom, metric)
        result.loc[anomaly_label, detector_label] = np.round(metric_value, 2)

result.style.background_gradient(cmap=cmap, vmin=0.5, vmax=1)
# Out:
# 100%|██████████| 14/14 [02:04<00:00,  8.92s/it]
# <style type="text/css">
# #T_f856b_row0_col0, #T_f856b_row0_col1, #T_f856b_row0_col4, #T_f856b_row0_col5, #T_f856b_row0_col6, #T_f856b_row0_col11, #T_f856b_row1_col0, #T_f856b_row1_col1, #T_f856b_row1_col4, #T_f856b_row1_col5, #T_f856b_row1_col6, #T_f856b_row5_col0, #T_f856b_row5_col1, #T_f856b_row5_col4, #T_f856b_row5_col5, #T_f856b_row5_col6, #T_f856b_row5_col11, #T_f856b_row8_col0, #T_f856b_row8_col1, #T_f856b_row8_col4, #T_f856b_row8_col5, #T_f856b_row8_col6, #T_f856b_row8_col11, #T_f856b_row10_col4, #T_f856b_row10_col5, #T_f856b_row10_col6, #T_f856b_row11_col4, #T_f856b_row11_col5, #T_f856b_row11_col6 {
#   background-color: #00ff00;
#   color: #000000;
# }
# #T_f856b_row0_col2, #T_f856b_row0_col10, #T_f856b_row1_col2, #T_f856b_row1_col9, #T_f856b_row1_col10, #T_f856b_row2_col0, #T_f856b_row2_col10, #T_f856b_row3_col10, #T_f856b_row3_col12, #T_f856b_row4_col2, #T_f856b_row4_col10, #T_f856b_row5_col9, #T_f856b_row6_col4, #T_f856b_row6_col5, #T_f856b_row7_col2, #T_f856b_row7_col3, #T_f856b_row9_col1, #T_f856b_row11_col9, #T_f856b_row11_col10 {
#   background-color: #f40b00;
#   color: #f1f1f1;
# }
# #T_f856b_row0_col3, #T_f856b_row1_col3, #T_f856b_row2_col3, #T_f856b_row2_col13, #T_f856b_row4_col3, #T_f856b_row6_col8 {
#   background-color: #e61900;
#   color: #f1f1f1;
# }
# #T_f856b_row0_col7, #T_f856b_row1_col7, #T_f856b_row2_col7, #T_f856b_row3_col0, #T_f856b_row3_col1, #T_f856b_row3_col4, #T_f856b_row3_col5, #T_f856b_row3_col6, #T_f856b_row3_col7, #T_f856b_row3_col11, #T_f856b_row3_col13, #T_f856b_row4_col7, #T_f856b_row5_col2, #T_f856b_row5_col10, #T_f856b_row6_col10, #T_f856b_row7_col0, #T_f856b_row7_col1, #T_f856b_row7_col10, #T_f856b_row8_col2, #T_f856b_row8_col10, #T_f856b_row9_col7, #T_f856b_row9_col9, #T_f856b_row9_col10, #T_f856b_row9_col13, #T_f856b_row10_col12, #T_f856b_row11_col13 {
#   background-color: #fe0100;
#   color: #f1f1f1;
# }
# #T_f856b_row0_col8, #T_f856b_row8_col8 {
#   background-color: #4cb300;
#   color: #f1f1f1;
# }
# #T_f856b_row0_col9, #T_f856b_row2_col1, #T_f856b_row4_col9, #T_f856b_row5_col3, #T_f856b_row5_col7, #T_f856b_row6_col7, #T_f856b_row6_col13, #T_f856b_row7_col7, #T_f856b_row8_col3, #T_f856b_row8_col7 {
#   background-color: #ea1500;
#   color: #f1f1f1;
# }
# #T_f856b_row0_col12, #T_f856b_row5_col12 {
#   background-color: #04fb00;
#   color: #000000;
# }
# #T_f856b_row0_col13 {
#   background-color: #c63900;
#   color: #f1f1f1;
# }
# #T_f856b_row1_col8 {
#   background-color: #46b900;
#   color: #f1f1f1;
# }
# #T_f856b_row1_col11, #T_f856b_row10_col2 {
#   background-color: #9e6100;
#   color: #f1f1f1;
# }
# #T_f856b_row1_col12 {
#   background-color: #b24d00;
#   color: #f1f1f1;
# }
# #T_f856b_row1_col13 {
#   background-color: #a85700;
#   color: #f1f1f1;
# }
# #T_f856b_row2_col2, #T_f856b_row5_col13, #T_f856b_row8_col13 {
#   background-color: #dc2300;
#   color: #f1f1f1;
# }
# #T_f856b_row2_col4 {
#   background-color: #6a9500;
#   color: #f1f1f1;
# }
# #T_f856b_row2_col5, #T_f856b_row2_col6 {
#   background-color: #2ed100;
#   color: #000000;
# }
# #T_f856b_row2_col8, #T_f856b_row9_col5 {
#   background-color: #946b00;
#   color: #f1f1f1;
# }
# #T_f856b_row2_col9, #T_f856b_row3_col9, #T_f856b_row6_col6, #T_f856b_row8_col9, #T_f856b_row11_col3 {
#   background-color: #f00f00;
#   color: #f1f1f1;
# }
# #T_f856b_row2_col11, #T_f856b_row2_col12, #T_f856b_row3_col2, #T_f856b_row3_col3, #T_f856b_row6_col0, #T_f856b_row6_col1, #T_f856b_row6_col2, #T_f856b_row6_col3, #T_f856b_row6_col9, #T_f856b_row6_col11, #T_f856b_row6_col12, #T_f856b_row7_col4, #T_f856b_row7_col5, #T_f856b_row7_col6, #T_f856b_row7_col9, #T_f856b_row7_col13, #T_f856b_row9_col0, #T_f856b_row9_col2, #T_f856b_row9_col3, #T_f856b_row9_col8, #T_f856b_row9_col11, #T_f856b_row9_col12, #T_f856b_row11_col2, #T_f856b_row11_col11 {
#   background-color: #fa0500;
#   color: #f1f1f1;
# }
# #T_f856b_row3_col8, #T_f856b_row10_col9 {
#   background-color: #e01f00;
#   color: #f1f1f1;
# }
# #T_f856b_row4_col0, #T_f856b_row4_col1, #T_f856b_row4_col4, #T_f856b_row4_col5, #T_f856b_row4_col6, #T_f856b_row4_col11, #T_f856b_row10_col1, #T_f856b_row10_col13 {
#   background-color: #28d700;
#   color: #000000;
# }
# #T_f856b_row4_col8, #T_f856b_row5_col8, #T_f856b_row11_col0 {
#   background-color: #50af00;
#   color: #f1f1f1;
# }
# #T_f856b_row4_col12 {
#   background-color: #32cd00;
#   color: #000000;
# }
# #T_f856b_row4_col13 {
#   background-color: #cc3300;
#   color: #f1f1f1;
# }
# #T_f856b_row7_col8 {
#   background-color: #56a900;
#   color: #f1f1f1;
# }
# #T_f856b_row7_col11 {
#   background-color: #c23d00;
#   color: #f1f1f1;
# }
# #T_f856b_row7_col12 {
#   background-color: #bc4300;
#   color: #f1f1f1;
# }
# #T_f856b_row8_col12 {
#   background-color: #0af500;
#   color: #000000;
# }
# #T_f856b_row9_col4 {
#   background-color: #a25d00;
#   color: #f1f1f1;
# }
# #T_f856b_row9_col6 {
#   background-color: #986700;
#   color: #f1f1f1;
# }
# #T_f856b_row10_col0, #T_f856b_row10_col8 {
#   background-color: #847b00;
#   color: #f1f1f1;
# }
# #T_f856b_row10_col3 {
#   background-color: #8e7100;
#   color: #f1f1f1;
# }
# #T_f856b_row10_col7 {
#   background-color: #7e8100;
#   color: #f1f1f1;
# }
# #T_f856b_row10_col10, #T_f856b_row10_col11 {
#   background-color: #b84700;
#   color: #f1f1f1;
# }
# #T_f856b_row11_col1 {
#   background-color: #18e700;
#   color: #000000;
# }
# #T_f856b_row11_col7 {
#   background-color: #d02f00;
#   color: #f1f1f1;
# }
# #T_f856b_row11_col8 {
#   background-color: #609f00;
#   color: #f1f1f1;
# }
# #T_f856b_row11_col12 {
#   background-color: #7a8500;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_f856b">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f856b_level0_col0" class="col_heading level0 col0" >SPE_52</th>
#       <th id="T_f856b_level0_col1" class="col_heading level0 col1" >SPE_59</th>
#       <th id="T_f856b_level0_col2" class="col_heading level0 col2" >T2_52</th>
#       <th id="T_f856b_level0_col3" class="col_heading level0 col3" >T2_59</th>
#       <th id="T_f856b_level0_col4" class="col_heading level0 col4" >AR_4</th>
#       <th id="T_f856b_level0_col5" class="col_heading level0 col5" >AR_16</th>
#       <th id="T_f856b_level0_col6" class="col_heading level0 col6" >MD</th>
#       <th id="T_f856b_level0_col7" class="col_heading level0 col7" >OCSVM_poly_0.01</th>
#       <th id="T_f856b_level0_col8" class="col_heading level0 col8" >LOF_5</th>
#       <th id="T_f856b_level0_col9" class="col_heading level0 col9" >IF_250</th>
#       <th id="T_f856b_level0_col10" class="col_heading level0 col10" >energy</th>
#       <th id="T_f856b_level0_col11" class="col_heading level0 col11" >TV</th>
#       <th id="T_f856b_level0_col12" class="col_heading level0 col12" >ZC</th>
#       <th id="T_f856b_level0_col13" class="col_heading level0 col13" >pk-pk</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f856b_level0_row0" class="row_heading level0 row0" >GWN</th>
#       <td id="T_f856b_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_f856b_row0_col1" class="data row0 col1" >1.000000</td>
#       <td id="T_f856b_row0_col2" class="data row0 col2" >0.520000</td>
#       <td id="T_f856b_row0_col3" class="data row0 col3" >0.550000</td>
#       <td id="T_f856b_row0_col4" class="data row0 col4" >1.000000</td>
#       <td id="T_f856b_row0_col5" class="data row0 col5" >1.000000</td>
#       <td id="T_f856b_row0_col6" class="data row0 col6" >1.000000</td>
#       <td id="T_f856b_row0_col7" class="data row0 col7" >0.500000</td>
#       <td id="T_f856b_row0_col8" class="data row0 col8" >0.850000</td>
#       <td id="T_f856b_row0_col9" class="data row0 col9" >0.540000</td>
#       <td id="T_f856b_row0_col10" class="data row0 col10" >0.520000</td>
#       <td id="T_f856b_row0_col11" class="data row0 col11" >1.000000</td>
#       <td id="T_f856b_row0_col12" class="data row0 col12" >0.990000</td>
#       <td id="T_f856b_row0_col13" class="data row0 col13" >0.610000</td>
#     </tr>
#     <tr>
#       <th id="T_f856b_level0_row1" class="row_heading level0 row1" >Impulse</th>
#       <td id="T_f856b_row1_col0" class="data row1 col0" >1.000000</td>
#       <td id="T_f856b_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_f856b_row1_col2" class="data row1 col2" >0.520000</td>
#       <td id="T_f856b_row1_col3" class="data ro

# %% [markdown]
# ## Save

# %%
path = os.path.join('results', f'results-data={data_type}-n={n}-delta={delta}.pkl')
result.to_pickle(path)
