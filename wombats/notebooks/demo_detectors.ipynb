# %%
import os
import sys
import numpy as np
import pandas as pd
from sklearn.metrics import roc_auc_score
import matplotlib.pyplot as plt
sys.path.append('..')
from anomalies.increasing import GWN
from detectors.feature_based import *
from detectors.pca_based import *
from detectors.gaussian_distribution_based import *
from detectors.ml_based import *

# %% [markdown]
# ## Load Data

# %%
n = 256
SNRdB = 40
ninst = 1_000
# load data train
path_train = os.path.join('..', 'datasets', 'ecg', f'ecgSyn_n={n}_scaled_train_snr={SNRdB}dB.pkl')
# process data
Xok_train = pd.read_pickle(path_train).dropna(axis=0)
Xok_train = Xok_train.values[:ninst, 0:n].reshape((ninst, -1))
# load data test
path_test = os.path.join('..', 'datasets', 'ecg', f'ecgSyn_n={n}_scaled_test_snr={SNRdB}dB.pkl')
# process data
Xok_test = pd.read_pickle(path_test).dropna(axis=0)
nch = 1
Xok_test = Xok_test.values[:ninst, 0:n].reshape((ninst, -1))
xok_test = Xok_test[0]

# %% [markdown]
# ## Setup

# %%
def dim_princ_sub(Xok, SNRdB=None):
    # theta corresponding to deviation delta
    N = Xok.shape[-2]
    n = Xok.shape[-1]
    Sok = 1/(N-1) * Xok.T @ Xok
    eigvals, eigvecs = np.linalg.eigh(Sok)
    lok = eigvals[::-1]
    Uok = eigvecs[:, ::-1]

    energy_per_component = np.sum(lok) / n

    # infer the dimension of the principal subspace (PS) k
    singvalues = np.sqrt(lok)
    if SNRdB is None:
        threshold = 2.858 * np.median(singvalues)
    else:
        sigma = 10**(-SNRdB/20)
        threshold = 4/np.sqrt(3) * sigma * np.sqrt(n)

    dim_princ_sub = np.sum(singvalues > threshold)
    if dim_princ_sub%2:
        dim_princ_sub = dim_princ_sub+1
    return dim_princ_sub

# %%
metric = 'P_D' #P_D, AUC
delta=0.1
k = dim_princ_sub(Xok_test, SNRdB)
kernel = 'rbf'
nu = 0.01
h = 5
l = 250
p = 16
detectors_labels = [f'SPE_{k}', f'T2_{k}', f'AR_{p}', f'OCSVM_{kernel}_{nu}', f'LOF_{h}',f'IF_{l}', 'MD', 'energy', 'TV', 'ZC', 'pk-pk']
detectors = [SPE(k), T2(k), AR(p), OCSVM(kernel, nu), LOF(h), IF(l), MD(), energy(), TV(), ZC(), pk_pk()]
detectors_dict = dict(zip(detectors_labels, detectors))

# %%
gwn = GWN(delta)
gwn.fit(Xok_test)
Xgwn_gwn = gwn.distort(Xok_test)
X_test = np.concatenate([Xok_test, Xgwn_gwn])

# %%
fig, ax = plt.subplots(len(detectors_dict.items()), sharex=True,
                       figsize=(8, 1.5*(len(detectors_dict.items()))))
for name, detector, ax_ in zip(detectors_dict.keys(), detectors_dict.values(), ax):
    scores = detector.fit(Xok_train).score(X_test)
    metric_value = detector.test(X_test, metric)
    ax_.plot(scores, label=f'{name}: {metric}={np.round(metric_value, 3)}')
    ax_.legend()
    ax_.grid()
    ax_.set(ylabel='score')
fig.tight_layout()
